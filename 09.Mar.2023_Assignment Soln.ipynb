# %% [markdown]
# **Q1: What are the Probability Mass Function (PMF) and Probability Density Function (PDF)? Explain with an example.**

# %% [markdown]
# **Ans** <br/>
# 1. Probability Mass Function (PMF)
#
# Definition:
# The PMF gives the probability that a discrete random variable takes on a specific value.
#
# It applies only to discrete random variables (like number of heads in coin tosses, number of students in a class).
#
# The probabilities are exact values and always satisfy:
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# ≥
# 0
# ,
# ∑
# 𝑥
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 1
# P(X=x)≥0,
# x
# ∑
# 	​
#
# P(X=x)=1
#
# Example (Coin Toss):
# Let
# 𝑋
# X = number of heads when tossing a fair coin once.
# Possible values:
# 𝑋
# ∈
# {
# 0
# ,
# 1
# }
# X∈{0,1}
#
# PMF:
#
# 𝑃
# (
# 𝑋
# =
# 0
# )
# =
# 0.5
# ,
# 𝑃
# (
# 𝑋
# =
# 1
# )
# =
# 0.5
# P(X=0)=0.5,P(X=1)=0.5
#
# So, the PMF is:
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# {
# 0.5
#
# 𝑥
# =
# 0
#
#
# 0.5
#
# 𝑥
# =
# 1
#
#
# 0
#
# otherwise
# P(X=x)=
# ⎩
# ⎨
# ⎧
# 	​
#
# 0.5
# 0.5
# 0
# 	​
#
# x=0
# x=1
# otherwise
# 	​
#
# 2. Probability Density Function (PDF)
#
# Definition:
# The PDF gives the relative likelihood for a continuous random variable to take on a value.
#
# It applies to continuous random variables (like height, weight, time).
#
# Unlike PMF, the probability at an exact point is always zero; instead, probability is defined over an interval:
#
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# =
# ∫
# 𝑎
# 𝑏
# 𝑓
# (
# 𝑥
# )
# 𝑑
# 𝑥
# P(a≤X≤b)=∫
# a
# b
# 	​
#
# f(x)dx
#
# PDF satisfies:
#
# 𝑓
# (
# 𝑥
# )
# ≥
# 0
# ,
# ∫
# −
# ∞
# ∞
# 𝑓
# (
# 𝑥
# )
# 𝑑
# 𝑥
# =
# 1
# f(x)≥0,∫
# −∞
# ∞
# 	​
#
# f(x)dx=1
#
# Example (Uniform Distribution):
# Let
# 𝑋
# X = outcome when picking a random number between 0 and 1.
# The PDF is:
#
# 𝑓
# (
# 𝑥
# )
# =
# {
# 1
#
# 0
# ≤
# 𝑥
# ≤
# 1
#
#
# 0
#
# otherwise
# f(x)={
# 1
# 0
# 	​
#
# 0≤x≤1
# otherwise
# 	​
#
#
# Here:
#
# 𝑃
# (
# 0.2
# ≤
# 𝑋
# ≤
# 0.5
# )
# =
# ∫
# 0.2
# 0.5
# 1
# 𝑑
# 𝑥
# =
# 0.3
# P(0.2≤X≤0.5)=∫
# 0.2
# 0.5
# 	​
#
# 1dx=0.3
#
# But
# 𝑃
# (
# 𝑋
# =
# 0.5
# )
# =
# 0
# P(X=0.5)=0 (since probability at a single point = 0).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import bernoulli, uniform

# -------------------------
# 1. PMF Example (Discrete)
# -------------------------
# Tossing a fair coin
p = 0.5  # probability of head
x_discrete = [0, 1]  # 0 = tail, 1 = head
pmf = bernoulli.pmf(x_discrete, p)

# -------------------------
# 2. PDF Example (Continuous)
# -------------------------
# Uniform distribution between 0 and 1
x_continuous = np.linspace(0, 1, 1000)
pdf = uniform.pdf(x_continuous, loc=0, scale=1)

# -------------------------
# Plotting
# -------------------------
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# Plot PMF
axs[0].bar(x_discrete, pmf, width=0.2, color="skyblue", edgecolor="black")
axs[0].set_title("PMF of Coin Toss (Discrete)")
axs[0].set_xlabel("X")
axs[0].set_ylabel("P(X)")
axs[0].set_xticks([0, 1])

# Plot PDF
axs[1].plot(x_continuous, pdf, color="red")
axs[1].fill_between(x_continuous, pdf, alpha=0.3, color="red")
axs[1].set_title("PDF of Uniform(0,1) (Continuous)")
axs[1].set_xlabel("X")
axs[1].set_ylabel("f(X)")

plt.tight_layout()
plt.show()

# %% [markdown]
# **Q2: What is Cumulative Density Function (CDF)? Explain with an example. Why CDF is used?**

# %% [markdown]
# 1. Definition: Cumulative Distribution Function (CDF)
#
# The Cumulative Distribution Function (CDF) gives the probability that a random variable
# 𝑋
# X is less than or equal to a certain value.
#
# 𝐹
# (
# 𝑥
# )
# =
# 𝑃
# (
# 𝑋
# ≤
# 𝑥
# )
# F(x)=P(X≤x)
#
# It is defined for both discrete and continuous random variables.
#
# Properties of CDF:
#
# 0
# ≤
# 𝐹
# (
# 𝑥
# )
# ≤
# 1
# 0≤F(x)≤1
#
# 𝐹
# (
# 𝑥
# )
# F(x) is non-decreasing
#
# lim
# ⁡
# 𝑥
# →
# −
# ∞
# 𝐹
# (
# 𝑥
# )
# =
# 0
# lim
# x→−∞
# 	​
#
# F(x)=0 and
# lim
# ⁡
# 𝑥
# →
# +
# ∞
# 𝐹
# (
# 𝑥
# )
# =
# 1
# lim
# x→+∞
# 	​
#
# F(x)=1
#
# 2. Example (Discrete – Dice Roll)
#
# Let
# 𝑋
# X = outcome of rolling a fair die (
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# 1,2,3,4,5,6).
#
# PMF:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 1
# 6
# ,
# 𝑘
# =
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# P(X=k)=
# 6
# 1
# 	​
#
# ,k=1,2,3,4,5,6
#
# CDF:
#
# 𝐹
# (
# 𝑥
# )
# =
# 𝑃
# (
# 𝑋
# ≤
# 𝑥
# )
# F(x)=P(X≤x)
#
# For example:
#
# 𝐹
# (
# 2
# )
# =
# 𝑃
# (
# 𝑋
# ≤
# 2
# )
# =
# 𝑃
# (
# 1
# )
# +
# 𝑃
# (
# 2
# )
# =
# 1
# 6
# +
# 1
# 6
# =
# 2
# 6
# F(2)=P(X≤2)=P(1)+P(2)=
# 6
# 1
# 	​
#
# +
# 6
# 1
# 	​
#
# =
# 6
# 2
# 	​
#
#
# 𝐹
# (
# 4
# )
# =
# 𝑃
# (
# 𝑋
# ≤
# 4
# )
# =
# 4
# 6
# F(4)=P(X≤4)=
# 6
# 4
# 	​
#
#
# 𝐹
# (
# 6
# )
# =
# 1
# F(6)=1
#
# So, the CDF is a step function that increases at each integer.
#
# 3. Example (Continuous – Uniform Distribution [0,1])
#
# Let
# 𝑋
# ∼
# 𝑈
# (
# 0
# ,
# 1
# )
# X∼U(0,1).
#
# PDF:
#
# 𝑓
# (
# 𝑥
# )
# =
# {
# 1
#
# 0
# ≤
# 𝑥
# ≤
# 1
#
#
# 0
#
# otherwise
# f(x)={
# 1
# 0
# 	​
#
# 0≤x≤1
# otherwise
# 	​
#
#
# CDF:
#
# 𝐹
# (
# 𝑥
# )
# =
# 𝑃
# (
# 𝑋
# ≤
# 𝑥
# )
# =
# ∫
# −
# ∞
# 𝑥
# 𝑓
# (
# 𝑡
# )
# 𝑑
# 𝑡
# =
# {
# 0
#
# 𝑥
# <
# 0
#
#
# 𝑥
#
# 0
# ≤
# 𝑥
# ≤
# 1
#
#
# 1
#
# 𝑥
# >
# 1
# F(x)=P(X≤x)=∫
# −∞
# x
# 	​
#
# f(t)dt=
# ⎩
# ⎨
# ⎧
# 	​
#
# 0
# x
# 1
# 	​
#
# x<0
# 0≤x≤1
# x>1
# 	​
#
#
# So here the CDF is a straight line between 0 and 1.
#
# 4. Why CDF is Used?
#
# To calculate probabilities over intervals easily:
#
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# =
# 𝐹
# (
# 𝑏
# )
# −
# 𝐹
# (
# 𝑎
# )
# P(a≤X≤b)=F(b)−F(a)
#
# Useful for both discrete & continuous cases.
#
# Helps in:
#
# Describing the entire probability distribution in one function.
#
# Comparing different distributions.
#
# Generating random variables in simulations.
#
# ✅ In short:
#
# PMF/PDF = probability at a point (discrete) or density (continuous).
#
# CDF = cumulative probability up to a point.
#
# We use CDF because it makes probability calculations (especially over ranges) easy.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint, uniform

# -------------------------
# 1. Discrete CDF (Dice Roll)
# -------------------------
dice = randint(1, 7)  # outcomes: 1 to 6
x_discrete = np.arange(1, 7)
cdf_dice = dice.cdf(x_discrete)

# -------------------------
# 2. Continuous CDF (Uniform [0,1])
# -------------------------
x_continuous = np.linspace(-0.5, 1.5, 500)
cdf_uniform = uniform.cdf(x_continuous, loc=0, scale=1)

# -------------------------
# Plotting
# -------------------------
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# Discrete CDF
axs[0].step(x_discrete, cdf_dice, where="post", color="blue")
axs[0].set_title("CDF of Dice Roll (Discrete)")
axs[0].set_xlabel("X")
axs[0].set_ylabel("F(X) = P(X ≤ x)")
axs[0].set_xticks(x_discrete)
axs[0].set_ylim(0, 1.1)

# Continuous CDF
axs[1].plot(x_continuous, cdf_uniform, color="red")
axs[1].set_title("CDF of Uniform(0,1) (Continuous)")
axs[1].set_xlabel("X")
axs[1].set_ylabel("F(X)")
axs[1].set_ylim(-0.1, 1.1)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Q3: What are some examples of situations where the normal distribution might be used as a model? Explain how the parameters of the normal distribution relate to the shape of the distribution.**

# %% [markdown]
# 1. Normal Distribution Recap
#
# A normal distribution (also called Gaussian distribution) is a continuous probability distribution shaped like a bell curve.
#
# Its Probability Density Function (PDF) is:
#
# 𝑓
# (
# 𝑥
# ∣
# 𝜇
# ,
# 𝜎
# )
# =
# 1
# 𝜎
# 2
# 𝜋
#
# 𝑒
# −
# (
# 𝑥
# −
# 𝜇
# )
# 2
# 2
# 𝜎
# 2
# f(x∣μ,σ)=
# σ
# 2π
# 	​
#
# 1
# 	​
#
# e
# −
# 2σ
# 2
# (x−μ)
# 2
# 	​
#
#
# where:
#
# 𝜇
# μ = mean (center)
#
# 𝜎
# σ = standard deviation (spread)
#
# 2. Examples of Normal Distribution in Real Life
#
# Normal distribution is commonly used because many natural and social phenomena follow it (due to the Central Limit Theorem).
#
# 🔹 Heights of people
#
# If you measure the height of many adults, most cluster around the average, with fewer very tall or very short individuals.
#
# 🔹 Exam scores
#
# In large classes, student scores often follow a bell-shaped curve: most get average marks, few get extremely high or low scores.
#
# 🔹 Measurement errors
#
# In experiments, errors due to random fluctuations usually follow a normal distribution.
#
# 🔹 Weight of manufactured products
#
# For example, if a factory produces 1kg sugar packets, the actual weight might be normally distributed around 1kg with some small deviation.
#
# 🔹 IQ scores
#
# IQ is designed to follow approximately a normal distribution with mean 100 and standard deviation 15.
#
# 3. Parameters and Shape
#
# The two parameters, mean (
# 𝜇
# μ) and standard deviation (
# 𝜎
# σ), define the distribution’s location and shape:
#
# Mean (
# 𝜇
# μ)
#
# Determines the center (peak) of the curve.
#
# Shifting
# 𝜇
# μ moves the entire curve left or right.
#
# Standard Deviation (
# 𝜎
# σ)
#
# Determines the spread/width of the curve.
#
# Small
# 𝜎
# σ: narrow & tall curve (values tightly clustered).
#
# Large
# 𝜎
# σ: wide & flat curve (values more spread out).
#
# 📌 Rule of Thumb (Empirical Rule):
#
# ~68% of values lie within
# 𝜇
# ±
# 1
# 𝜎
# μ±1σ
#
# ~95% within
# 𝜇
# ±
# 2
# 𝜎
# μ±2σ
#
# ~99.7% within
# 𝜇
# ±
# 3
# 𝜎
# μ±3σ
#
# 4. Visualization Idea
#
# If you plot three normal distributions:
#
# 𝜇
# =
# 0
# ,
# 𝜎
# =
# 1
# μ=0,σ=1 (standard normal)
#
# 𝜇
# =
# 0
# ,
# 𝜎
# =
# 2
# μ=0,σ=2 (wider spread)
#
# 𝜇
# =
# 2
# ,
# 𝜎
# =
# 1
# μ=2,σ=1 (shifted right)
# → you’ll clearly see how mean shifts the curve and sigma changes spread.
#
# ✅ In summary:
#
# Normal distribution is widely used in heights, exam scores, measurement errors, IQ, product quality etc.
#
# Mean (
# 𝜇
# μ) = location of center
#
# Standard deviation (
# 𝜎
# σ) = spread/width of curve

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# X range for plotting
x = np.linspace(-10, 10, 1000)

# Different Normal distributions
distributions = [
    {"mu": 0, "sigma": 1, "color": "blue", "label": "μ=0, σ=1 (Standard Normal)"},
    {"mu": 0, "sigma": 2, "color": "red", "label": "μ=0, σ=2 (Wider Spread)"},
    {"mu": 2, "sigma": 1, "color": "green", "label": "μ=2, σ=1 (Shifted Right)"}
]

# Plot each distribution
plt.figure(figsize=(10, 6))
for dist in distributions:
    mu, sigma = dist["mu"], dist["sigma"]
    y = norm.pdf(x, mu, sigma)
    plt.plot(x, y, color=dist["color"], label=dist["label"])

# Formatting the plot
plt.title("Effect of Mean (μ) and Standard Deviation (σ) on Normal Distribution")
plt.xlabel("X")
plt.ylabel("Probability Density f(X)")
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# **Q4: Explain the importance of Normal Distribution. Give a few real-life examples of Normal Distribution.**

# %% [markdown]
# 1. Importance of Normal Distribution
#
# The normal distribution is one of the most important concepts in statistics and data science because:
#
# Central Limit Theorem (CLT):
#
# Many random processes, when combined (like sums or averages of samples), tend to become normally distributed even if the original data is not.
#
# This makes the normal distribution a universal model in probability and statistics.
#
# Many natural & social phenomena follow it:
#
# Human traits (height, weight, IQ, exam scores, etc.) naturally cluster around an average.
#
# Basis for statistical inference:
#
# Hypothesis testing, confidence intervals, regression, and many machine learning algorithms assume data is approximately normal.
#
# Predictability:
#
# The shape is completely determined by just two parameters:
#
# Mean (μ) = center
#
# Standard Deviation (σ) = spread
#
# This makes it mathematically simple and powerful.
#
# Error distribution:
#
# Random errors and noise in measurements often follow a normal distribution, so it’s essential in quality control and signal processing.
#
# 2. Real-Life Examples of Normal Distribution
#
# Here are some common situations:
#
# 🔹 Human Characteristics:
#
# Heights of adult men and women.
#
# Weights of people in a population.
#
# IQ scores (mean = 100, σ = 15).
#
# 🔹 Education & Performance:
#
# Exam/test scores in a large class.
#
# Average marks usually cluster around a mean, with fewer very high or very low scores.
#
# 🔹 Manufacturing & Quality Control:
#
# Dimensions of machine-made parts (e.g., diameter of bolts, weight of sugar packets).
#
# Small deviations from the target value are normally distributed due to random errors.
#
# 🔹 Finance & Economics:
#
# Stock returns (over short time intervals).
#
# Income distributions in certain controlled populations.
#
# 🔹 Natural & Scientific Phenomena:
#
# Measurement errors in experiments.
#
# Distribution of blood pressure or cholesterol levels in a population.
#
# Lifespan of electronic components (sometimes modeled approximately as normal).
#
# ✅ In short:
#
# The normal distribution is important because it naturally appears in many real-world processes, is supported by the Central Limit Theorem, and forms the foundation for much of statistical analysis.
#
# Examples: heights, weights, IQ, exam scores, product quality, and measurement errors.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# X ranges for each case
x_heights = np.linspace(130, 210, 500)   # Height range in cm
x_iq = np.linspace(40, 160, 500)        # IQ range

# Normal distributions
heights_pdf = norm.pdf(x_heights, loc=170, scale=10)  # mean=170, sd=10
iq_pdf = norm.pdf(x_iq, loc=100, scale=15)            # mean=100, sd=15

# Plotting
plt.figure(figsize=(12, 5))

# Heights
plt.subplot(1, 2, 1)
plt.plot(x_heights, heights_pdf, color="blue", label="Heights (μ=170, σ=10)")
plt.fill_between(x_heights, heights_pdf, alpha=0.3, color="blue")
plt.title("Normal Distribution: Heights of Adult Males")
plt.xlabel("Height (cm)")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(alpha=0.3)

# IQ
plt.subplot(1, 2, 2)
plt.plot(x_iq, iq_pdf, color="green", label="IQ (μ=100, σ=15)")
plt.fill_between(x_iq, iq_pdf, alpha=0.3, color="green")
plt.title("Normal Distribution: IQ Scores")
plt.xlabel("IQ")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# * Left (Heights): Bell curve centered at 170 cm, most people around that height, few very tall/short.
#
# * Right (IQ): Bell curve centered at IQ=100, showing the classic IQ distribution where ~68% fall between 85 and 115.

# %% [markdown]
# **Q5: What is Bernaulli Distribution? Give an Example. What is the difference between Bernoulli Distribution and Binomial Distribution?**

# %% [markdown]
# 1. Bernoulli Distribution
#
# A Bernoulli distribution is the simplest probability distribution.
#
# It models a random variable with only two outcomes:
#
# Success (1) with probability
# 𝑝
# p
#
# Failure (0) with probability
# 1
# −
# 𝑝
# 1−p
#
# PMF (Probability Mass Function):
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# {
# 𝑝
#
# if
# 𝑥
# =
# 1
#
#
# 1
# −
# 𝑝
#
# if
# 𝑥
# =
# 0
# P(X=x)={
# p
# 1−p
# 	​
#
# if x=1
# if x=0
# 	​
#
#
# Mean (Expected value):
# 𝜇
# =
# 𝑝
# μ=p
#
# Variance:
# 𝜎
# 2
# =
# 𝑝
# (
# 1
# −
# 𝑝
# )
# σ
# 2
# =p(1−p)
#
# 2. Example of Bernoulli Distribution
#
# Tossing a coin (success = Head, failure = Tail):
#
# 𝑝
# =
# 0.5
# p=0.5
#
# Outcomes:
#
# 𝑃
# (
# 𝑋
# =
# 1
# )
# =
# 0.5
# P(X=1)=0.5 (Head)
#
# 𝑃
# (
# 𝑋
# =
# 0
# )
# =
# 0.5
# P(X=0)=0.5 (Tail)
#
# Another example: Passing an exam (success = Pass, failure = Fail).
#
# 3. Binomial Distribution
#
# The Binomial distribution is basically the sum of several independent Bernoulli trials.
#
# It models the number of successes in
# 𝑛
# n independent Bernoulli trials, each with success probability
# 𝑝
# p.
#
# PMF:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# ,
# 𝑘
# =
# 0
# ,
# 1
# ,
# 2
# ,
# …
# ,
# 𝑛
# P(X=k)=(
# k
# n
# 	​
#
# )p
# k
# (1−p)
# n−k
# ,k=0,1,2,…,n
#
# Mean:
# 𝜇
# =
# 𝑛
# 𝑝
# μ=np
#
# Variance:
# 𝜎
# 2
# =
# 𝑛
# 𝑝
# (
# 1
# −
# 𝑝
# )
# σ
# 2
# =np(1−p)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import bernoulli, binom

# -------------------------
# Bernoulli Distribution (single trial)
# -------------------------
p = 0.5  # probability of success
x_bern = [0, 1]
pmf_bern = bernoulli.pmf(x_bern, p)

# -------------------------
# Binomial Distribution (multiple trials)
# -------------------------
n = 10  # number of trials
x_binom = np.arange(0, n+1)
pmf_binom = binom.pmf(x_binom, n, p)

# -------------------------
# Plotting
# -------------------------
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# Bernoulli Distribution
axs[0].bar(x_bern, pmf_bern, width=0.2, color="skyblue", edgecolor="black")
axs[0].set_title("Bernoulli Distribution (p=0.5)")
axs[0].set_xlabel("X (Outcome)")
axs[0].set_ylabel("P(X)")
axs[0].set_xticks([0, 1])

# Binomial Distribution
axs[1].bar(x_binom, pmf_binom, width=0.6, color="orange", edgecolor="black")
axs[1].set_title("Binomial Distribution (n=10, p=0.5)")
axs[1].set_xlabel("X (Number of Successes)")
axs[1].set_ylabel("P(X)")

plt.tight_layout()
plt.show()

# %% [markdown]
# <ul>
# <li>Left (Bernoulli, p=0.5): Two bars → Success (1) with probability 0.5, Failure (0) with probability 0.5.
# <li>Right (Binomial, n=10, p=0.5): A bell-shaped bar plot showing distribution of successes (0–10).
# <li>Peak around 5 (the expected number of heads in 10 tosses).
# <ul/>

# %% [markdown]
# **Q6. Consider a dataset with a mean of 50 and a standard deviation of 10. If we assume that the dataset is normally distributed, what is the probability that a randomly selected observation will be greater than 60? Use the appropriate formula and show your calculations.**

# %% [markdown]
# Given:
# 𝑋
# ∼
# 𝑁
# (
# 𝜇
# =
# 50
# ,
#
# 𝜎
# =
# 10
# )
# X∼N(μ=50, σ=10).
# We want
# 𝑃
# (
# 𝑋
# >
# 60
# )
# P(X>60).
#
# Standardize to Z:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# =
# 60
# −
# 50
# 10
# =
# 1
# Z=
# σ
# X−μ
# 	​
#
# =
# 10
# 60−50
# 	​
#
# =1
#
# Use the standard normal CDF
# Φ
# (
# 𝑧
# )
# Φ(z):
#
# 𝑃
# (
# 𝑋
# >
# 60
# )
# =
# 𝑃
# (
# 𝑍
# >
# 1
# )
# =
# 1
# −
# Φ
# (
# 1
# )
# P(X>60)=P(Z>1)=1−Φ(1)
#
# From Z-table (or CDF):
# Φ
# (
# 1
# )
# ≈
# 0.8413
# Φ(1)≈0.8413
#
# Answer:
#
# 𝑃
# (
# 𝑋
# >
# 60
# )
# =
# 1
# −
# 0.8413
# =
# 0.1587
# P(X>60)=1−0.8413=0.1587
#
# Result: \boxed{\approx 0.1587 \text{ (about 15.87%)} }.

# %% [markdown]
# **Q7: Explain uniform Distribution with an example.**

# %% [markdown]
# 1. Definition of Uniform Distribution
#
# The Uniform distribution is a probability distribution where all outcomes are equally likely within a certain range.
#
# Two main types:
#
# Discrete Uniform Distribution → finite number of equally likely outcomes.
#
# Continuous Uniform Distribution → any value within an interval has equal probability.
#
# 2. Continuous Uniform Distribution
#
# If a random variable
# 𝑋
# X is uniformly distributed between
# 𝑎
# a and
# 𝑏
# b:
#
# 𝑋
# ∼
# 𝑈
# (
# 𝑎
# ,
# 𝑏
# )
# X∼U(a,b)
#
# PDF (Probability Density Function):
#
# 𝑓
# (
# 𝑥
# )
# =
# {
# 1
# 𝑏
# −
# 𝑎
#
# for
# 𝑎
# ≤
# 𝑥
# ≤
# 𝑏
#
#
# 0
#
# otherwise
# f(x)={
# b−a
# 1
# 	​
#
# 0
# 	​
#
# for a≤x≤b
# otherwise
# 	​
#
#
# CDF (Cumulative Distribution Function):
#
# 𝐹
# (
# 𝑥
# )
# =
# {
# 0
#
# 𝑥
# <
# 𝑎
#
#
# 𝑥
# −
# 𝑎
# 𝑏
# −
# 𝑎
#
# 𝑎
# ≤
# 𝑥
# ≤
# 𝑏
#
#
# 1
#
# 𝑥
# >
# 𝑏
# F(x)=
# ⎩
# ⎨
# ⎧
# 	​
#
# 0
# b−a
# x−a
# 	​
#
# 1
# 	​
#
# x<a
# a≤x≤b
# x>b
# 	​
#
#
# Mean:
# 𝜇
# =
# 𝑎
# +
# 𝑏
# 2
# μ=
# 2
# a+b
# 	​
#
#
# Variance:
# 𝜎
# 2
# =
# (
# 𝑏
# −
# 𝑎
# )
# 2
# 12
# σ
# 2
# =
# 12
# (b−a)
# 2
# 	​
#
#
# 3. Example (Continuous)
#
# Suppose a bus arrives randomly anytime between 0 and 10 minutes.
#
# Here,
# 𝑋
# ∼
# 𝑈
# (
# 0
# ,
# 10
# )
# X∼U(0,10).
#
# The probability of waiting between 2 and 5 minutes:
#
# 𝑃
# (
# 2
# ≤
# 𝑋
# ≤
# 5
# )
# =
# ∫
# 2
# 5
# 1
# 10
# 𝑑
# 𝑥
# =
# 5
# −
# 2
# 10
# =
# 0.3
# P(2≤X≤5)=∫
# 2
# 5
# 	​
#
# 10
# 1
# 	​
#
# dx=
# 10
# 5−2
# 	​
#
# =0.3
#
# So, there is a 30% chance you’ll wait between 2 and 5 minutes.
#
# 4. Example (Discrete)
#
# Rolling a fair die:
# 𝑋
# ∼
# {
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# }
# X∼{1,2,3,4,5,6}.
#
# Each outcome has equal probability:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 1
# 6
# ,
# 𝑘
# =
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# P(X=k)=
# 6
# 1
# 	​
#
# ,k=1,2,3,4,5,6
#
# ✅ In short:
#
# Uniform Distribution = Equal likelihood.
#
# Continuous example: Bus waiting time.
#
# Discrete example: Rolling a fair die.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# 1. Continuous Uniform Distribution (Bus Waiting Time)
a, b = 0, 10  # interval
x = np.linspace(-2, 12, 1000)
pdf = uniform.pdf(x, a, b-a)

# 2. Discrete Uniform Distribution (Die Roll)
die_faces = np.arange(1, 7)
die_probs = np.ones(6) / 6

# Plot Continuous Uniform
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(x, pdf, 'b', lw=2)
plt.fill_between(x, pdf, 0, alpha=0.3, color='skyblue')
plt.title("Continuous Uniform Distribution (Bus waiting time 0–10 min)")
plt.xlabel("x")
plt.ylabel("Probability Density")

# Highlight probability of waiting between 2 and 5 minutes
highlight_x = np.linspace(2, 5, 100)
plt.fill_between(highlight_x, uniform.pdf(highlight_x, a, b-a), 0, alpha=0.5, color="orange", label="P(2 ≤ X ≤ 5) = 0.3")
plt.legend()

# Plot Discrete Uniform (Die Roll)
plt.subplot(1,2,2)
plt.bar(die_faces, die_probs, color='lightgreen', edgecolor='black')
plt.title("Discrete Uniform Distribution (Fair Die Roll)")
plt.xlabel("Die Face")
plt.ylabel("Probability")
plt.xticks(die_faces)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Q8: What is the z score? State the importance of the z score.**

# %% [markdown]
# A Z-score (also called standard score) tells us how many standard deviations a data point is from the mean of the distribution.
#
# The formula is:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# 	​
#
#
# 𝑋
# X = the value we are analyzing
#
# 𝜇
# μ = mean of the dataset
#
# 𝜎
# σ = standard deviation
#
# 2. Example
#
# Suppose test scores are normally distributed with:
#
# Mean (
# 𝜇
# μ) = 70
#
# Standard deviation (
# 𝜎
# σ) = 10
#
# A student scores
# 𝑋
# =
# 85
# X=85.
#
# 𝑍
# =
# 85
# −
# 70
# 10
# =
# 15
# 10
# =
# 1.5
# Z=
# 10
# 85−70
# 	​
#
# =
# 10
# 15
# 	​
#
# =1.5
#
# ➡️ This means the student scored 1.5 standard deviations above the mean.
#
# 3. Importance of Z-Score
#
# ✅ Standardization → Converts different datasets into a common scale (mean = 0, std dev = 1).
#
# ✅ Comparison → Helps compare values from different distributions (e.g., comparing exam scores from different subjects).
#
# ✅ Probability calculation → Used with the standard normal distribution table to calculate probabilities.
#
# ✅ Outlier detection → Large positive or negative Z-scores (e.g., |Z| > 3) often indicate outliers.
#
# ✅ Basis for many statistical tests → Hypothesis testing, confidence intervals, and machine learning preprocessing.
#
# 👉 In short: The Z-score is a way to measure “how unusual” or “how far” a value is from the average, in terms of standard deviations.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import zscore

# Sample dataset (exam scores)
data = [65, 70, 72, 68, 90, 85, 100, 55, 60, 73, 71, 69, 95, 40, 120]

# Convert to DataFrame
df = pd.DataFrame(data, columns=["Score"])

# Calculate Z-scores
df["Z_Score"] = zscore(df["Score"])

# Identify outliers (|Z| > 3 is usually considered outlier)
df["Outlier"] = df["Z_Score"].apply(lambda x: "Yes" if abs(x) > 3 else "No")

print(df)

# Plotting
plt.figure(figsize=(10,5))
plt.scatter(df.index, df["Score"], c=(df["Outlier"]=="Yes"), cmap="coolwarm", s=100)
plt.axhline(np.mean(data), color="green", linestyle="--", label="Mean")
plt.title("Z-Score Outlier Detection")
plt.xlabel("Index")
plt.ylabel("Score")
plt.legend()
plt.show()
# Out:
#     Score   Z_Score Outlier
# 0      65 -0.552110      No
# 1      70 -0.290033      No
# 2      72 -0.185202      No
# 3      68 -0.394864      No
# 4      90  0.758278      No
# 5      85  0.496200      No
# 6     100  1.282433      No
# 7      55 -1.076265      No
# 8      60 -0.814188      No
# 9      73 -0.132786      No
# 10     71 -0.237617      No
# 11     69 -0.342448      No
# 12     95  1.020355      No
# 13     40 -1.862498      No
# 14    120  2.330744      No

# %% [markdown]
# Creates a dataset of exam scores.
#
# Calculates Z-scores using scipy.stats.zscore.
#
# Flags outliers where
# ∣
# 𝑍
# ∣
# >
# 3
# ∣Z∣>3.
#
# Plots the scores, highlighting outliers in a different color.

# %% [markdown]
# **Q9: What is Central Limit Theorem? State the significance of the Central Limit Theorem.**

# %% [markdown]
# Central Limit Theorem (CLT)
#
# 👉 The Central Limit Theorem states that:
#
# If we take random samples of sufficiently large size (n) from any population with mean (μ) and standard deviation (σ), then the sampling distribution of the sample mean will be approximately normal (bell-shaped), regardless of the shape of the original population distribution.
#
# In other words:
#
# Even if the population is not normal (e.g., skewed, uniform, etc.), the distribution of the sample means will approach a normal distribution as the sample size increases.
#
# The larger the sample size (n ≥ 30 is a common rule of thumb), the better the approximation.
#
# Mathematical Representation
#
# If
# 𝑋
# 1
# ,
# 𝑋
# 2
# ,
# .
# .
# .
# ,
# 𝑋
# 𝑛
# X
# 1
# 	​
#
# ,X
# 2
# 	​
#
# ,...,X
# n
# 	​
#
#  are independent random samples from a population with:
#
# Mean =
# 𝜇
# μ
#
# Standard Deviation =
# 𝜎
# σ
#
# Then the sampling distribution of the mean
# 𝑋
# ˉ
# X
# ˉ
#  has:
#
# Mean:
# 𝜇
# 𝑋
# ˉ
# =
# 𝜇
# μ
# X
# ˉ
# 	​
#
# =μ
#
# Standard Error:
# 𝜎
# 𝑋
# ˉ
# =
# 𝜎
# 𝑛
# σ
# X
# ˉ
# 	​
#
# =
# n
# 	​
#
# σ
# 	​
#
#
# Shape: Approximately Normal (for large n).
#
# Significance of CLT
#
# Foundation of Inferential Statistics
#
# Allows us to use Normal distribution for hypothesis testing and confidence intervals, even when population distribution is unknown.
#
# Enables Prediction
#
# With CLT, we can make predictions about sample means (like exam scores, production quality, etc.) using Z-scores.
#
# Real-World Applications
#
# Quality Control: In factories, checking a sample of items instead of every item.
#
# Polling: Political surveys rely on sample means approximating population opinions.
#
# Finance: Stock market returns analysis.
#
# Real-Life Example
#
# Imagine a factory producing light bulbs:
#
# Lifespan of bulbs may follow a skewed distribution (some burn out early, some last very long).
#
# If we take random samples of 50 bulbs and calculate the average lifespan, the distribution of those averages will be normal, thanks to CLT.
#
# This allows engineers to apply normal probability methods to estimate bulb quality.
#
# ✨ In short:
# The Central Limit Theorem is important because it justifies why the Normal distribution is so widely used in statistics and machine learning, even when the population itself is not normal.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)

# Population distribution: Exponential (highly skewed, not normal)
population = np.random.exponential(scale=2, size=100000)

# Function to draw sample means
def sample_means(sample_size, num_samples=1000):
    means = [np.mean(np.random.choice(population, sample_size)) for _ in range(num_samples)]
    return means

# Different sample sizes to illustrate CLT
sample_sizes = [5, 30, 100]

plt.figure(figsize=(15, 5))

for i, n in enumerate(sample_sizes, 1):
    means = sample_means(n)
    plt.subplot(1, 3, i)
    plt.hist(means, bins=30, density=True, color="skyblue", edgecolor="black")
    plt.title(f"Sample Size = {n}", fontsize=12)
    plt.xlabel("Sample Mean")
    plt.ylabel("Frequency")

plt.suptitle("Central Limit Theorem Demonstration\n(Population: Exponential, Skewed)", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# Here’s a visual demonstration of the Central Limit Theorem (CLT):
#
# The population is taken from an Exponential distribution, which is skewed (not normal).
#
# We take many random samples of different sizes (n = 5, 30, 100) and compute their means.
#
# 👉 Observations:
#
# For small sample size (n=5), the sample means still look skewed.
#
# As the sample size increases (n=30, n=100), the distribution of the sample means becomes more bell-shaped (Normal Distribution).
#
# ✅ This proves the CLT: Regardless of the population’s shape, the distribution of sample means tends to be normal as sample size increases.

# %% [markdown]
# **Q10: State the assumptions of the Central Limit Theorem.**

# %% [markdown]
# Assumptions of CLT
#
# Independence of Observations
#
# The samples must be drawn independently.
#
# That means the outcome of one observation should not affect another.
#
# Random Sampling
#
# The data should be obtained through random sampling (or random assignment).
#
# This ensures unbiased representation of the population.
#
# Sample Size
#
# A large enough sample size is required for the CLT to hold.
#
# Rule of thumb:
#
# For fairly symmetric distributions, n ≥ 30 is usually enough.
#
# For very skewed or heavy-tailed distributions, a larger sample size may be needed.
#
# Finite Variance & Mean
#
# The population must have a finite mean (μ) and finite variance (σ²).
#
# CLT does not work if variance is infinite (e.g., Cauchy distribution).
#
# Summary
#
# If we take large, random, independent samples from a population with finite variance, then the distribution of sample means will approximate a Normal Distribution, regardless of the original population’s distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)

# 1. Example where CLT works: Exponential distribution (skewed but finite variance)
exp_samples = [np.mean(np.random.exponential(scale=2, size=50)) for _ in range(10000)]

# 2. Example where CLT fails: Cauchy distribution (infinite variance)
cauchy_samples = [np.mean(np.random.standard_cauchy(size=50)) for _ in range(10000)]

# Plotting
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Exponential (CLT works, sample means ~ Normal)
axs[0].hist(exp_samples, bins=50, density=True, color='skyblue', edgecolor='black')
axs[0].set_title("Sample Means of Exponential Dist. (CLT works)")

# Cauchy (CLT fails, no convergence to Normal)
axs[1].hist(cauchy_samples, bins=50, density=True, color='salmon', edgecolor='black')
axs[1].set_xlim(-25, 25)  # limit x for visibility
axs[1].set_title("Sample Means of Cauchy Dist. (CLT fails)")

plt.tight_layout()
plt.show()

# %% [markdown]
# Here’s a visualization of the assumptions of the Central Limit Theorem (CLT) in practice:
#
# Left (Exponential Distribution):
# Even though the exponential distribution is skewed, its sample means (from repeated sampling) form a bell-shaped curve. This shows the CLT working because the distribution has a finite mean and variance.
#
# Right (Cauchy Distribution):
# The Cauchy distribution has no finite mean or variance, so the CLT assumptions are violated. As a result, the sample means do not converge to a normal distribution, and the distribution remains irregular.
#
# 👉 This demonstrates that CLT requires finite mean and variance. Without these, the theorem doesn’t hold.
